# %% [markdown]
# **- Connect to drive:**

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# **- Extract zip file:**

# %%
path_of_zip_file = "/content/drive/MyDrive/UIT Projects/Khai thác dữ liệu/source/datasets/card_transaction.zip"

destination_path = "/content/my_example_folder"

# %%
# !unzip "$path_of_zip_file" -d "$destination_path"
# Out:
# Archive:  /content/drive/MyDrive/UIT Projects/Khai thác dữ liệu/source/datasets/card_transaction.zip
#   inflating: /content/my_example_folder/card_transaction.csv

# %% [markdown]
# **- Example of using extracted file:**

# %%
import pandas as pd

# File ví dụ này nặng 2.19GB nên pandas load hơi lâu
# nhưng vì đã giải nén về colab nên nó vẫn nhanh hơn rất nhiều so với load trực tiếp từ drive

path_of_extracted_file = "/content/my_example_folder/card_transaction.csv"

df = pd.read_csv(path_of_extracted_file)
df.head(10)
# Out:
#    User  Card  Year  Month  Day   Time   Amount           Use Chip  \
# 0     0     0  2002      9    1  06:21  $134.09  Swipe Transaction
# 1     0     0  2002      9    1  06:42   $38.48  Swipe Transaction
# 2     0     0  2002      9    2  06:22  $120.34  Swipe Transaction
# 3     0     0  2002      9    2  17:45  $128.95  Swipe Transaction
# 4     0     0  2002      9    3  06:23  $104.71  Swipe Transaction
# 5     0     0  2002      9    3  13:53   $86.19  Swipe Transaction
# 6     0     0  2002      9    4  05:51   $93.84  Swipe Transaction
# 7     0     0  2002      9    4  06:09  $123.50  Swipe Transaction
# 8     0     0  2002      9    5  06:14   $61.72  Swipe Transaction
# 9     0     0  2002      9    5  09:35   $57.10  Swipe Transaction
#
#          Merchant Name  Merchant City Merchant State      Zip   MCC Errors?  \
# 0  3527213246127876953       La Verne             CA  91750.0  5300     NaN
# ...
